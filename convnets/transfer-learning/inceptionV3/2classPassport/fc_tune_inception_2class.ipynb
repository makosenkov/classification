# %%
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from convnets.utilities import utils_nets as utils

# %%
# dimensions of our images.
img_width, img_height = 224, 224

# structure_path = '/home/mksnkv/models/top_tuned/vgg16/structure_passport.json'
# weights_path_mcp = '/home/mksnkv/models/top_tuned/vgg16/snils_model_mcp.h5'
train_data_dir = '../../../../data/passport_2class_divided_clean/train'
validation_data_dir = '../../../../data/passport_2class_divided_clean/validation'
nb_train_samples = 480
nb_validation_samples = 130
nb_evaluation_samples = 780
epochs = 20
batch_size = 5

# %%
def train_top_model():
    base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(img_width, img_height, 3))
    model = Sequential()

    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    for layer in base_model.layers:
        layer.trainable = False
#     for layer in base_model.layers:
#         print(layer)
    model.summary()
    opt = Adam(learning_rate=1e-5)
    model.compile(optimizer=opt,
                  loss='binary_crossentropy', metrics=['accuracy'])

    # mcp_save = ModelCheckpoint(weights_path_mcp, save_best_only=True, monitor='val_loss', mode='min')
    # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
    history = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            validation_data=val_generator,
            validation_steps=nb_validation_samples // batch_size)
    return model, history

# %%
train_generator, val_generator = utils.init_generators(train_data_dir,
                                                       validation_data_dir,
                                                       img_width,
                                                       img_height,
                                                       batch_size,
                                                       batch_size)
# Out:
# Found 480 images belonging to 2 classes.
# Found 130 images belonging to 2 classes.

# %%
model, history = train_top_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 34,910,497
# Trainable params: 13,107,713
# Non-trainable params: 21,802,784
# _________________________________________________________________
# WARNING:tensorflow:From <ipython-input-3-381cd34e3d6f>:28: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 96/96 [==============================] - 13s 132ms/step - loss: 0.3420 - accuracy: 0.8521 - val_loss: 0.0594 - val_accuracy: 0.9846
# Epoch 2/20
# 96/96 [==============================] - 12s 121ms/step - loss: 0.0719 - accuracy: 0.9812 - val_loss: 0.0289 - val_accuracy: 0.9923
# Epoch 3/20
# 96/96 [==============================] - 12s 120ms/step - loss: 0.0303 - accuracy: 0.9896 - val_loss: 0.0146 - val_accuracy: 1.0000
# Epoch 4/20
# 96/96 [==============================] - 12s 120ms/step - loss: 0.0552 - accuracy: 0.9833 - val_loss: 0.0126 - val_accuracy: 1.0000
# Epoch 5/20
# 96/96 [==============================] - 12s 121ms/step - loss: 0.0324 - accuracy: 0.9875 - val_loss: 0.0184 - val_accuracy: 0.9846
# Epoch 6/20
# 96/96 [==============================] - 12s 121ms/step - loss: 0.0216 - accuracy: 0.9896 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 7/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0117 - accuracy: 0.9979 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 8/20
# 96/96 [==============================] - 12s 121ms/step - loss: 0.0258 - accuracy: 0.9896 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 9/20
# 96/96 [==============================] - 11s 120ms/step - loss: 0.0136 - accuracy: 0.9979 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 10/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0215 - accuracy: 0.9917 - val_loss: 0.0055 - val_accuracy: 1.0000
# Epoch 11/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0227 - accuracy: 0.9937 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 12/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0187 - accuracy: 0.9917 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 13/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0085 - accuracy: 0.9958 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 14/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0160 - accuracy: 0.9979 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 15/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0082 - accuracy: 0.9958 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 16/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0161 - accuracy: 0.9937 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 17/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 18/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0169 - accuracy: 0.9917 - val_loss: 0.0199 - val_accuracy: 0.9846
# Epoch 19/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0093 - accuracy: 0.9979 - val_loss: 0.0099 - val_accuracy: 0.9923
# Epoch 20/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0159 - accuracy: 0.9958 - val_loss: 0.0064 - val_accuracy: 1.0000

# %%
utils.plot(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model.save("../../../../data/weights/inception_passport.h5")
