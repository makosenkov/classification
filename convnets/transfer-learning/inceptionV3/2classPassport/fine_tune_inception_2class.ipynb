# %%
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from convnets.utilities import utils_nets as utils

# %%
# dimensions of our images.
img_width, img_height = 224, 224

# structure_path = '/home/mksnkv/models/top_tuned/vgg16/structure_passport.json'
# weights_path_mcp = '/home/mksnkv/models/top_tuned/vgg16/snils_model_mcp.h5'
train_data_dir = '../../../../data/passport_2class_divided_clean/train'
validation_data_dir = '../../../../data/passport_2class_divided_clean/validation'
nb_train_samples = 480
nb_validation_samples = 130
nb_evaluation_samples = 780
epochs = 20
batch_size = 5

# %%
def train_top_model():
    base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(img_width, img_height, 3))
    model = Sequential()

    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    for layer in base_model.layers[:-12]:
        layer.trainable = False
#     for layer in base_model.layers:
#         print(layer)
    model.summary()
    opt = Adam(learning_rate=1e-5)
    model.compile(optimizer=opt,
                  loss='binary_crossentropy', metrics=['accuracy'])

    # mcp_save = ModelCheckpoint(weights_path_mcp, save_best_only=True, monitor='val_loss', mode='min')
    # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
    history = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            validation_data=val_generator,
            validation_steps=nb_validation_samples // batch_size)
    return model, history

# %%
train_generator, val_generator = utils.init_generators(train_data_dir,
                                                       validation_data_dir,
                                                       img_width,
                                                       img_height,
                                                       batch_size,
                                                       batch_size)
# Out:
# Found 480 images belonging to 2 classes.
# Found 130 images belonging to 2 classes.

# %%
model, history = train_top_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# inception_v3 (Model)         (None, 5, 5, 2048)        21802784
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               13107456
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 34,910,497
# Trainable params: 13,501,441
# Non-trainable params: 21,409,056
# _________________________________________________________________
# WARNING:tensorflow:From <ipython-input-3-dbe9a11c02e7>:28: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 96/96 [==============================] - 13s 134ms/step - loss: 0.3063 - accuracy: 0.8542 - val_loss: 0.0406 - val_accuracy: 0.9846
# Epoch 2/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0832 - accuracy: 0.9708 - val_loss: 0.0297 - val_accuracy: 0.9923
# Epoch 3/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0440 - accuracy: 0.9875 - val_loss: 0.0199 - val_accuracy: 0.9923
# Epoch 4/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0495 - accuracy: 0.9833 - val_loss: 0.0205 - val_accuracy: 0.9923
# Epoch 5/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0494 - accuracy: 0.9812 - val_loss: 0.0062 - val_accuracy: 1.0000
# Epoch 6/20
#  - ETA: 5s - loss: 0.0234 - accuracy: 0.9902
# Epoch 7/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 8/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0166 - accuracy: 0.9937 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 9/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0213 - accuracy: 0.9917 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 10/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0282 - accuracy: 0.9875 - val_loss: 0.0044 - val_accuracy: 1.0000
# Epoch 11/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 12/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0194 - accuracy: 0.9937 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 13/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0186 - accuracy: 0.9917 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 14/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 15/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0088 - accuracy: 0.9958 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 16/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 17/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0050 - accuracy: 0.9979 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 18/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 19/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0024 - val_accuracy: 1.0000
# Epoch 20/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 0.9923

# %%
utils.plot(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model.save("../../../../data/weights/inception/inception_passport_fine_tuned.h5")
