# %%
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from convnets.utilities import utils_nets as utils

# %%
# dimensions of our images.
img_width, img_height = 224, 224

# structure_path = '/home/mksnkv/models/top_tuned/vgg16/structure_passport.json'
# weights_path_mcp = '/home/mksnkv/models/top_tuned/vgg16/snils_model_mcp.h5'
train_data_dir = '../../../../data/passport_2class_divided_clean/train'
validation_data_dir = '../../../../data/passport_2class_divided_clean/validation'
nb_train_samples = 480
nb_validation_samples = 130
epochs = 20
batch_size = 5

# %%
def train_top_model():
    base_model = VGG16(include_top=False, weights='imagenet', input_shape=(img_width, img_height, 3))
    model = Sequential()
    
    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    for layer in base_model.layers[:-4]:
        layer.trainable = False
    # for layer in base_model.layers:
    #     layer.trainable = False
    model.summary()
    opt = Adam(learning_rate=1e-5)
    model.compile(optimizer=opt,
                  loss='binary_crossentropy', metrics=['accuracy'])

    # mcp_save = ModelCheckpoint(weights_path_mcp, save_best_only=True, monitor='val_loss', mode='min')
    # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
    history = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            # callbacks = [mcp_save],
            validation_data=val_generator,
            validation_steps=nb_validation_samples // batch_size)
    return model, history

# %%
train_generator, val_generator = utils.init_generators(train_data_dir, 
                                                       validation_data_dir, 
                                                       img_width, 
                                                       img_height, 
                                                       batch_size,
                                                       batch_size)
# Out:
# Found 480 images belonging to 2 classes.
# Found 130 images belonging to 2 classes.

# %%
model, history = train_top_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               6422784
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 21,137,729
# Trainable params: 13,502,465
# Non-trainable params: 7,635,264
# _________________________________________________________________
# WARNING:tensorflow:From <ipython-input-3-018ebf46d719>:29: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.3741 - accuracy: 0.8271 - val_loss: 0.1268 - val_accuracy: 0.9385
# Epoch 2/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0855 - accuracy: 0.9729 - val_loss: 0.0939 - val_accuracy: 0.9615
# Epoch 3/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0463 - accuracy: 0.9833 - val_loss: 0.0415 - val_accuracy: 0.9846
# Epoch 4/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 5/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0179 - accuracy: 0.9958 - val_loss: 0.0228 - val_accuracy: 0.9846
# Epoch 6/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0100 - accuracy: 0.9958 - val_loss: 0.0090 - val_accuracy: 0.9923
# Epoch 7/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0293 - accuracy: 0.9896 - val_loss: 0.0275 - val_accuracy: 0.9846
# Epoch 8/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0282 - val_accuracy: 0.9923
# Epoch 9/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0165 - val_accuracy: 0.9923
# Epoch 10/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0113 - val_accuracy: 0.9923
# Epoch 11/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0120 - accuracy: 0.9917 - val_loss: 0.0145 - val_accuracy: 0.9923
# Epoch 12/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0216 - val_accuracy: 0.9923
# Epoch 13/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0044 - accuracy: 0.9979 - val_loss: 0.0213 - val_accuracy: 0.9923
# Epoch 14/20
#  - ETA: 3s - loss: 0.0020 - accuracy: 1.0000
# Epoch 15/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0265 - val_accuracy: 0.9923
# Epoch 16/20
# 96/96 [==============================] - 12s 126ms/step - loss: 5.8954e-04 - accuracy: 1.0000 - val_loss: 0.0164 - val_accuracy: 0.9923
# Epoch 17/20
#  - ETA: 0s - loss: 4.1719e-04 - accuracy: 1.0000
# Epoch 18/20
# 96/96 [==============================] - 12s 128ms/step - loss: 8.5918e-04 - accuracy: 1.0000 - val_loss: 0.0271 - val_accuracy: 0.9923
# Epoch 19/20
# 96/96 [==============================] - 12s 128ms/step - loss: 1.8914e-04 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9923
# Epoch 20/20
# 96/96 [==============================] - 12s 128ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9846

# %%
utils.plot(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
