# %%
from tensorflow.keras import applications
from tensorflow.keras import optimizers
from tensorflow.keras.models import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dropout, Flatten, Dense
import tensorflow as tf
import cv2
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt

img_width, img_height = 224, 224

weights_path = '/home/mksnkv/models/top_tuned/vgg16/sved_model_mcp.h5'
evaluation_data_dir = '/home/mksnkv/Documents/classification/sved_2class_divided_clean/evaluation'
model = load_model(weights_path)


datagen = ImageDataGenerator(rescale=1. / 255)
generator = datagen.flow_from_directory(
        evaluation_data_dir,
        target_size=(img_width, img_height),
        batch_size=1,
        class_mode='binary',
        shuffle=False)

model.evaluate(generator)
# Out:
# Found 443 images belonging to 2 classes.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 443/443 [==============================] - 37s 83ms/step - loss: 0.0999 - accuracy: 0.9842
# [0.09993360477271761, 0.98419863]

# %%
dover_dir = '/home/mksnkv/Documents/classification/dover_2class_divided_clean/train/dover/'
ndfl_dir = '/home/mksnkv/Documents/classification/ndfl_2class_divided_clean/train/ndfl/'
snils_dir = '/home/mksnkv/Documents/classification/snils_2class_divided_clean/train/snils/'
sved_dir = '/home/mksnkv/Documents/classification/sved_2class_divided_clean/train/sved/'
passport_dir = '/home/mksnkv/Documents/classification/passport_2class_divided_clean/evaluation/passport/'

eval_dir = '/home/mksnkv/Documents/classification/passport_2class_divided_clean/evaluation/non-passport/'

error_counter = 0
directory = dover_dir
images = os.listdir(directory)

filenames = []
imgs = []
for name in images:
    img = cv2.imread(directory + name)
    image = cv2.resize(img,(224,224))
    image = np.reshape(image,[1,224,224,3])
    image = tf.cast(image, tf.float32)
    classes = model(image, training=False)
    print(classes)
#     if float(classes[0]) < 0.5:
#         error_counter = error_counter + 1
#         filenames.append(name)
#         imgs.append(img)
#         info = str(error_counter) + "/" + str(len(images))  + " name: " + name + " confidence:" + str(float(classes[0]))
#         print(info)
# Out:
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# tf.Tensor([[0.]], shape=(1, 1), dtype=float32)
# ...

# %%
dir_split = directory.split("/")
original_label = dir_split[len(dir_split) - 2]
for i in range(len(filenames)):
    title = 'Original label:{}, Prediction :{}, filename:{}'.format(
        original_label,
        "non-" + original_label,
        filenames[i]
        )
    image = imgs[i]
    plt.figure(figsize=[7,7])
    plt.axis('off')
    plt.title(title)
    plt.imshow(image)
    plt.show()
