# %%
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from convnets.utilities import utils_nets as utils

# %%
# dimensions of our images.
img_width, img_height = 224, 224

# structure_path = '/home/mksnkv/models/top_tuned/vgg16/structure_passport.json'
# weights_path_mcp = '/home/mksnkv/models/top_tuned/vgg16/snils_model_mcp.h5'
train_data_dir = '../../../../data/passport_2class_divided_clean/train'
validation_data_dir = '../../../../data/passport_2class_divided_clean/validation'
nb_train_samples = 480
nb_validation_samples = 130
nb_evaluation_samples = 780
epochs = 20
batch_size = 5

# %%
def train_top_model():
    base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(img_width, img_height, 3))
    model = Sequential()

    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    for layer in base_model.layers[:-12]:
        layer.trainable = False
    # for layer in base_model.layers:
    #     print(layer)
        layer.trainable = False
    model.summary()
    opt = Adam(learning_rate=1e-5)
    model.compile(optimizer=opt,
                  loss='binary_crossentropy', metrics=['accuracy'])

    # mcp_save = ModelCheckpoint(weights_path_mcp, save_best_only=True, monitor='val_loss', mode='min')
    # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
    history = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            validation_data=val_generator,
            validation_steps=nb_validation_samples // batch_size)
    return model, history

# %%
train_generator, val_generator = utils.init_generators(train_data_dir,
                                                       validation_data_dir,
                                                       img_width,
                                                       img_height,
                                                       batch_size,
                                                       batch_size)
# Out:
# Found 480 images belonging to 2 classes.
# Found 130 images belonging to 2 classes.

# %%
model, history = train_top_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               12845312
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 19,883,073
# Trainable params: 13,050,561
# Non-trainable params: 6,832,512
# _________________________________________________________________
# WARNING:tensorflow:From <ipython-input-3-f4e3eda344ad>:29: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 96/96 [==============================] - 14s 143ms/step - loss: 0.3632 - accuracy: 0.8333 - val_loss: 0.1171 - val_accuracy: 0.9462
# Epoch 2/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.1365 - accuracy: 0.9500 - val_loss: 0.0324 - val_accuracy: 0.9923
# Epoch 3/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.1108 - accuracy: 0.9542 - val_loss: 0.0447 - val_accuracy: 0.9846
# Epoch 4/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0645 - accuracy: 0.9708 - val_loss: 0.0120 - val_accuracy: 0.9923
# Epoch 5/20
#  - ETA: 2s - loss: 0.0636 - accuracy: 0.9824
# Epoch 6/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0486 - accuracy: 0.9812 - val_loss: 0.0138 - val_accuracy: 0.9923
# Epoch 7/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0388 - accuracy: 0.9937 - val_loss: 0.0130 - val_accuracy: 0.9923
# Epoch 8/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0471 - accuracy: 0.9812 - val_loss: 0.0097 - val_accuracy: 0.9923
# Epoch 9/20
# 96/96 [==============================] - 12s 121ms/step - loss: 0.0262 - accuracy: 0.9875 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 10/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0603 - accuracy: 0.9771 - val_loss: 0.0156 - val_accuracy: 0.9923
# Epoch 11/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0279 - accuracy: 0.9958 - val_loss: 0.0112 - val_accuracy: 0.9923
# Epoch 12/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0099 - val_accuracy: 0.9923
# Epoch 13/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0338 - accuracy: 0.9896 - val_loss: 0.0117 - val_accuracy: 0.9923
# Epoch 14/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0148 - val_accuracy: 0.9923
# Epoch 15/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0181 - accuracy: 0.9937 - val_loss: 0.0086 - val_accuracy: 0.9923
# Epoch 16/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0273 - accuracy: 0.9896 - val_loss: 0.0223 - val_accuracy: 0.9923
# Epoch 17/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0256 - accuracy: 0.9937 - val_loss: 0.0305 - val_accuracy: 0.9923
# Epoch 18/20
#  - ETA: 1s - loss: 0.0168 - accuracy: 0.9952
# Epoch 19/20
# 96/96 [==============================] - 12s 128ms/step - loss: 0.0103 - accuracy: 0.9958 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 20/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.0211 - val_accuracy: 0.9923

# %%
utils.plot(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model.save("../../../../data/weights/densenet/densenet_passport_fine_tuned.h5")
