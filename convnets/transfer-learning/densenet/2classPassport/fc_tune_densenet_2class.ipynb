# %%
from tensorflow.keras.applications import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from convnets.utilities import utils_nets as utils

# %%
# dimensions of our images.
img_width, img_height = 224, 224

# structure_path = '/home/mksnkv/models/top_tuned/vgg16/structure_passport.json'
# weights_path_mcp = '/home/mksnkv/models/top_tuned/vgg16/snils_model_mcp.h5'
train_data_dir = '../../../../data/passport_2class_divided_clean/train'
validation_data_dir = '../../../../data/passport_2class_divided_clean/validation'
nb_train_samples = 480
nb_validation_samples = 130
nb_evaluation_samples = 780
epochs = 20
batch_size = 5

# %%
def train_top_model():
    base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(img_width, img_height, 3))
    model = Sequential()

    model.add(base_model)
    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))

    # for layer in base_model.layers[:-12]:
    #     layer.trainable = False
    for layer in base_model.layers:
        print(layer)
        layer.trainable = False
    model.summary()
    opt = Adam(learning_rate=1e-5)
    model.compile(optimizer=opt,
                  loss='binary_crossentropy', metrics=['accuracy'])

    # mcp_save = ModelCheckpoint(weights_path_mcp, save_best_only=True, monitor='val_loss', mode='min')
    # es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
    history = model.fit_generator(
            generator=train_generator,
            steps_per_epoch=nb_train_samples // batch_size,
            epochs=epochs,
            validation_data=val_generator,
            validation_steps=nb_validation_samples // batch_size)
    return model, history

# %%
train_generator, val_generator = utils.init_generators(train_data_dir,
                                                       validation_data_dir,
                                                       img_width,
                                                       img_height,
                                                       batch_size,
                                                       batch_size)
# Out:
# Found 480 images belonging to 2 classes.
# Found 130 images belonging to 2 classes.

# %%
model, history = train_top_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 6s 0us/step
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x0000025CB924AF28>
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x0000025CB250EFD0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025CB92C4CC0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025CB92FE710>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025CB9315DA0>
# <tensorflow.python.keras.layers.convolutional.ZeroPadding2D object at 0x0000025CB9315E10>
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x0000025CBF6D67F0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025CBF6E1668>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025CB5C09CC0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025CBF6E97B8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025CBF8D31D0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025CBF8D3DD8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025CBF8D3C18>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025CBFAC6048>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025CBFAC6550>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025CBFC20A58>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025CBFC20438>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025CBFC7A400>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025CBFC855F8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025CBFC857F0>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025CBFF2C198>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025CBFF2CB70>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025CBFF33128>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025CBFF33160>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025CBFF8E4A8>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025CBFF996D8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025CBFF998D0>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE4A61278>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4A61C50>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4A69208>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4A69518>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4AC3588>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4ACD7B8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4ACD9B0>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE4B27358>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4B27D30>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4B2E2E8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4B2E5F8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4B89668>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4B94898>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4B94A90>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE4BEB470>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4BF6748>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4BF6438>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4BF66A0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4C4D7F0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4C54940>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4C54D68>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE4CB25F8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4CB9AC8>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4CB95C0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4CB9828>
# <tensorflow.python.keras.layers.pooling.AveragePooling2D object at 0x0000025DE4D1B780>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4D1BB38>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4D1B908>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4D23CC0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4D7E390>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4D84630>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4D84C50>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE4DE1198>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4DE1B70>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4DE5128>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4DE5160>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4E444E0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4E4C710>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4E4C908>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE4EA7320>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4EA7CF8>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4EAF2B0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4EAF5C0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4F08668>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4F13898>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4F13A90>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE4F6C470>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4F75748>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4F75438>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4F756A0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE4FCE7F0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE4FD7940>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE4FD7D68>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE50305F8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE503AAC8>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE503A5C0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE503A828>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE509C5C0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE509CB00>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE509CC50>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE50F6780>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE5100C50>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE5100748>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE51009B0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE5160128>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE5160C18>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE5160D30>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE51BD978>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE51C3240>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE51C3898>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE51C3710>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE61F6048>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE61F67F0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE61F6EB8>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE625A4A8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE625A438>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE625AF98>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE6262358>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE62BD198>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE62BDDD8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025D

# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9B28940>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE9B80358>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9B80D30>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9B892E8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9B895F8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9BE56A0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9BED8D0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9BEDAC8>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE9C474A8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9C50978>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9C50470>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9C506D8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9CA9828>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9CB3978>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9CB3DA0>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE9D0B630>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9D12B00>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9D125F8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9D12860>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9D76780>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9D76B38>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9D76C88>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE9DD27B8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9DD9C88>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9DD9320>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9DD99E8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9E3E240>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9E3EF60>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9E3EC88>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE9E98FD0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9E9E278>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9E9E8D0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9E9E748>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9F010F0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9F01BE0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9F01D30>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DE9F624A8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9F62470>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9F62FD0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9F6C390>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DE9FC6048>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DE9FC6E10>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DE9FC69B0>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEA02A198>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA02A5F8>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA02A7B8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA0320B8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA08A048>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA08AF98>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA096438>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEA0EE160>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA0EE780>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA0F7160>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA0F79B0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA14E1D0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA14EDD8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA156518>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEA1B20F0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA1B29B0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA1BC358>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA1BC080>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA214358>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA2195F8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA219C18>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEA278160>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA278B38>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA27C0F0>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA27C198>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA2DA4A8>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA2E56D8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA2E58D0>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEA33C2E8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA33CCC0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA341278>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA341588>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA3A2630>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA3AA860>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA3AAA58>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEA405438>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA409710>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA409400>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA4095F8>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA4677B8>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA46E9E8>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA46EAC8>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEA4CA5C0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEA4D2A90>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEA4D2588>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEA4D27F0>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEB4FEFD0>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEB503A20>
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x0000025DEB503E10>
# <tensorflow.python.keras.layers.merge.Concatenate object at 0x0000025DEB55C748>
# <tensorflow.python.keras.layers.normalization_v2.BatchNormalization object at 0x0000025DEB566C18>
# <tensorflow.python.keras.layers.core.Activation object at 0x0000025DEB5662B0>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 256)               12845312
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 19,883,073
# Trainable params: 12,845,569
# Non-trainable params: 7,037,504
# _________________________________________________________________
# WARNING:tensorflow:From <ipython-input-3-3776999ac484>:29: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 96/96 [==============================] - 14s 143ms/step - loss: 0.3197 - accuracy: 0.8625 - val_loss: 0.0300 - val_accuracy: 1.0000
# Epoch 2/20
# 96/96 [==============================] - 12s 121ms/step - loss: 0.0539 - accuracy: 0.9917 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 3/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0292 - accuracy: 0.9979 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 4/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0292 - accuracy: 0.9896 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 5/20
# 96/96 [==============================] - 12s 127ms/step - loss: 0.0155 - accuracy: 0.9979 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 6/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 7/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0238 - accuracy: 0.9937 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 8/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 9/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0120 - accuracy: 0.9937 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 10/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0080 - accuracy: 0.9979 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 11/20
# 96/96 [==============================] - 12s 128ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 12/20
# 96/96 [==============================] - 12s 122ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 13/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0098 - accuracy: 0.9979 - val_loss: 0.0095 - val_accuracy: 0.9923
# Epoch 14/20
# 96/96 [==============================] - 12s 126ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 15/20
# 96/96 [==============================] - 12s 123ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 16/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 17/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 18/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0039 - accuracy: 0.9979 - val_loss: 0.0061 - val_accuracy: 1.0000
# Epoch 19/20
# 96/96 [==============================] - 12s 124ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 20/20
# 96/96 [==============================] - 12s 125ms/step - loss: 0.0048 - accuracy: 0.9979 - val_loss: 0.0140 - val_accuracy: 0.9923

# %%
utils.plot(history)
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model.save("../../../../data/weights/densenet/densenet_passport_fc.h5")
